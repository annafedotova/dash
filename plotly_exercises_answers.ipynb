# %% [markdown]
# # Introduction to Plotly
#
# Let's start by importing the necessary libraries.
#
# Plotly can be used in offline and online modes. When in online mode, all the graphs you create will be saved in your Plotly account online. But there is a limit of graphs you can create for free, so you either have to constantly delete your graphs from your account or pay.
#
# The good news is that you can use offline mode where your graphs are only displayed in your Jupyter Notebook and are not saved online. There are no limitations as to the number of graphs you can create in offline mode.
#
# **Note:** apparently starting from plotly version 4.0 released in July 2019, the offline mode is used by default, and the online functionality is moved to a separate package called `chart-studio` (more on Plotly version 4.0 [here](https://medium.com/plotly/plotly-py-4-0-is-here-offline-only-express-first-displayable-anywhere-fc444e5659ee)). So depending on the Plotly version you have, you might not need to specify that you want to use offline mode explicitly.

# %%
# pandas and numpy to work with datasets
import pandas as pd
import numpy as np

# plotly imports for Plotly visualizations
import plotly.plotly as py
import plotly.graph_objs as go
# inititate Plotly offline mode
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

# cufflinks to create Plotly viz with simplified syntax
import cufflinks as cf
# inititate cufflinks offline mode
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Dataset exploration
#
# We will use data about OECD countries meat consumption from [Data World](https://data.world/oecd/meat-consumption).
#
#
# **Summary**
#
# Meat consumption is related to living standards, diet, livestock production and consumer prices, as well as macroeconomic uncertainty and shocks to GDP. Compared to other commodities, meat is characterised by high production costs and high output prices. Meat demand is associated with higher incomes and a shift - due to urbanisation - to food consumption changes that favour increased proteins from animal sources in diets. While the global meat industry provides food and a livelihood for billions of people, it also has significant environmental and health consequences for the planet. This indicator is presented for beef and veal, pig, poultry, and sheep. Meat consumption is measured in thousand tonnes of carcass weight (except for poultry expressed as ready to cook weight) and in kilograms of retail weight per capita. Carcass weight to retail weight conversion factors are: 0.7 for beef and veal, 0.78 for pigmeat, and 0.88 for both sheep meat and poultry meat.

# %%
# loading dataset into pandas dataframe
df = pd.read_csv('meat_consumption_clean.csv')

# %%
# print out first 5 rows of the dataset
df.head()
# Out:
#   LOCATION    INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1990   0.000004         NaN
# 1      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1991  27.808401         NaN
# 2      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1992  26.278166         NaN
# 3      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1993  26.244478         NaN
# 4      AUS  MEATCONSUMP    BEEF  KG_CAP         A  1994  25.541244         NaN

# %%
# get the number of rows and columns in the dataset
df.shape
# Out:
# (9020, 8)

# %%
# get a sense of values in each column of the dataset
df.describe(include='all')
# Out:
#        LOCATION    INDICATOR SUBJECT     MEASURE FREQUENCY         TIME  \
# count      9020         9020    9020        9020      9020  9020.000000
# unique       39            1       4           2         1          NaN
# top         SAU  MEATCONSUMP   SHEEP  THND_TONNE         A          NaN
# freq        232         9020    2255        4524      9020          NaN
# mean        NaN          NaN     NaN         NaN       NaN  2004.041242
# std         NaN          NaN     NaN         NaN       NaN     8.347088
# min         NaN          NaN     NaN         NaN       NaN  1990.000000
# 25%         NaN          NaN     NaN         NaN       NaN  1997.000000
# 50%         NaN          NaN     NaN         NaN       NaN  2004.000000
# 75%         NaN          NaN     NaN         NaN       NaN  2011.000000
# max         NaN          NaN     NaN         NaN       NaN  2018.000000
#
#                Value  Flag Codes
# count   9.020000e+03         0.0
# unique           NaN         NaN
# top              NaN         NaN
# freq             NaN         NaN
# mean    2.014624e+03         NaN
# std     9.320713e+03         NaN
# min     7.505681e-08         NaN
# 25%     4.567496e+00         NaN
# 50%     2.325614e+01         NaN
# 75%     3.916184e+02         NaN
# max     1.221729e+05         NaN

# %%
# get the list of unique countries
df.LOCATION.unique()
# Out:
# array(['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
#        'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
#        'ISR', 'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL', 'RUS',
#        'SAU', 'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'EU27', 'OECD', 'BRICS',
#        'NOR', 'CHE', 'GBR'], dtype=object)

# %%
# get the list of unique meat types
df.SUBJECT.unique()
# Out:
# array(['BEEF', 'PIG', 'POULTRY', 'SHEEP'], dtype=object)

# %%
# get the list of unique measures
df.MEASURE.unique()
# Out:
# array(['KG_CAP', 'THND_TONNE'], dtype=object)

# %% [markdown]
# Since there are 2 different measures of meat consumption in this dataset, let's separate it into 2 datasets:
#
# - `df_total` with total meat consumption in thousand tonnes of carcass weight
# - `df_per_cap` with meat consumption measured in kilogramms per capita of retail weight

# %%
# split the dataset into 2 based on the measure
df_total =  df.query('MEASURE == "THND_TONNE"')
df_per_cap = df.query('MEASURE == "KG_CAP"')

# %% [markdown]
# ## Building graphs with Plotly
#
# The native syntax of Plotly includes 3 main components:
#
# - **Data**
#
# The Data object defines the data that will be displayed in the graph.
#
# - **Layout**
#
# The Layout object defines all additional features of the graph, like title, axis titles, etc.
#
# - **Figure**
#
# The Figure object brings together the Data and the Layout and creates the graph to be plotted.
#
#
# You can find full Plotly documentation for Python [here](https://plot.ly/python/).
#
# Let's start by building a simple line chart summarizing the evolution of total meat consumption by year.

# %%
# remove OECD, BRICS
df_total_clean = df_total.query('~LOCATION.isin(["OECD","BRICS"])')

# group by year
df_total_year = df_total_clean.groupby('TIME').Value.sum().round(0).reset_index()
df_total_year
# Out:
#     TIME     Value
# 0   1990  218203.0
# 1   1991  238417.0
# 2   1992  260198.0
# 3   1993  277449.0
# 4   1994  292060.0
# 5   1995  302593.0
# 6   1996  303447.0
# 7   1997  320615.0
# 8   1998  332461.0
# 9   1999  341410.0
# 10  2000  430161.0
# 11  2001  438483.0
# 12  2002  453547.0
# 13  2003  461973.0
# 14  2004  469940.0
# 15  2005  481864.0
# 16  2006  496697.0
# 17  2007  506330.0
# 18  2008  521975.0
# 19  2009  527523.0
# 20  2010  544439.0
# 21  2011  551565.0
# 22  2012  564106.0
# 23  2013  576559.0
# 24  2014  585890.0
# 25  2015  595643.0
# 26  2016  603474.0
# 27  2017  608799.0
# 28  2018  615118.0

# %%
# save the split datasets to csv for further use
df_total_clean.to_csv('df_total.csv', index=False)
df_per_cap.to_csv('df_per_cap.csv', index=False)

# %% [markdown]
# This would be the full syntax for defining the figure as one object at once:

# %%
fig = go.Figure(
        data=[
            go.Scatter(x=df_total_year.TIME, 
                       y=df_total_year.Value,
                       mode='lines')
        ],
        layout=go.Layout(
            title=dict(text='Total Meat Consumption Evolution'),
            xaxis=dict(title='Year'),
            yaxis=dict(title='Meat consumption, thousand tonnes')
        )
    )
fig.show()
# Out:
# <div>
#
#
#             <div id="933ed709-44fe-47d3-b81b-5240c1883c10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("933ed709-44fe-47d3-b81b-5240c1883c10")) {
#                     Plotly.newPlot(
#                         '933ed709-44fe-47d3-b81b-5240c1883c10',
#                         [{"mode": "lines", "type": "scatter", "uid": "48566f39-ee30-4aeb-a104-a08247865ec7", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [218203.0, 238417.0, 260198.0, 277449.0, 292060.0, 302593.0, 303447.0, 320615.0, 332461.0, 341410.0, 430161.0, 438483.0, 453547.0, 461973.0, 469940.0, 481864.0, 496697.0, 506330.0, 521975.0, 527523.0, 544439.0, 551565.0, 564106.0, 576559.0, 585890.0, 595643.0, 603474.0, 608799.0, 615118.0]}],
#                         {"title": {"text": "Total Meat Consumption Evolution"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Meat consumption, thousand tonnes"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('933ed709-44fe-47d3-b81b-5240c1883c10');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# This is a more step by step way to define the same graph, using methods `add_trace` and `layout.update` on the figure object.

# %%
fig = go.Figure()
# create a data trace 
fig.add_trace(go.Scatter(x=df_total_year.TIME, 
                         y=df_total_year.Value,
                         mode='lines'))
# edit the layout
fig.layout.update(title='Total Meat Consumption Evolution',
                   xaxis_title='Year',
                   yaxis_title='Meat consumption, thousand tonnes')
fig.show()
# Out:
# <div>
#
#
#             <div id="770252db-74cf-4b60-aae6-7ace28ff4dcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("770252db-74cf-4b60-aae6-7ace28ff4dcf")) {
#                     Plotly.newPlot(
#                         '770252db-74cf-4b60-aae6-7ace28ff4dcf',
#                         [{"mode": "lines", "type": "scatter", "uid": "23033471-81f6-4759-9086-4621f6e9cf00", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [218203.0, 238417.0, 260198.0, 277449.0, 292060.0, 302593.0, 303447.0, 320615.0, 332461.0, 341410.0, 430161.0, 438483.0, 453547.0, 461973.0, 469940.0, 481864.0, 496697.0, 506330.0, 521975.0, 527523.0, 544439.0, 551565.0, 564106.0, 576559.0, 585890.0, 595643.0, 603474.0, 608799.0, 615118.0]}],
#                         {"title": {"text": "Total Meat Consumption Evolution"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Meat consumption, thousand tonnes"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('770252db-74cf-4b60-aae6-7ace28ff4dcf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Now let's build a multiple lines chart, adding a split by type of meat to the previous graph.

# %%
# create a dataframe with meat consumption by type by year
df_year_type = df_total_clean.groupby(['TIME', 'SUBJECT']).Value.sum().round(0).reset_index()
df_year_type
# Out:
#      TIME  SUBJECT     Value
# 0    1990     BEEF   71089.0
# 1    1990      PIG   84457.0
# 2    1990  POULTRY   50556.0
# 3    1990    SHEEP   12101.0
# 4    1991     BEEF   74012.0
# ..    ...      ...       ...
# 111  2017    SHEEP   25284.0
# 112  2018     BEEF  128188.0
# 113  2018      PIG  232923.0
# 114  2018  POULTRY  228455.0
# 115  2018    SHEEP   25552.0
#
# [116 rows x 3 columns]

# %% [markdown]
# To plot the results easily, let's pivot this dataframe, so that each column represents a type of meat and each row represents a year and on the intersection we have the actual value of thousands of tonnes of meat consumed.

# %%
# pivot the dataframe using pivot_table function
df_year_type_pivot = df_year_type.pivot_table(index='TIME', columns='SUBJECT', values='Value').reset_index()
df_year_type_pivot
# Out:
# SUBJECT  TIME      BEEF       PIG   POULTRY    SHEEP
# 0        1990   71089.0   84457.0   50556.0  12101.0
# 1        1991   74012.0   89966.0   61594.0  12845.0
# 2        1992   82849.0   95298.0   68323.0  13728.0
# 3        1993   83594.0  105873.0   73748.0  14234.0
# 4        1994   86789.0  111632.0   78938.0  14700.0
# 5        1995   88620.0  113009.0   85820.0  15144.0
# 6        1996   89579.0  112443.0   87003.0  14421.0
# 7        1997   91603.0  120809.0   92962.0  15241.0
# 8        1998   91595.0  128588.0   96502.0  15777.0
# 9        1999   93681.0  129884.0  101826.0  16019.0
# 10       2000  108500.0  173950.0  127861.0  19851.0
# 11       2001  108742.0  177211.0  132802.0  19728.0
# 12       2002  112613.0  181784.0  139134.0  20016.0
# 13       2003  114247.0  184613.0  142583.0  20529.0
# 14       2004  115762.0  186480.0  146405.0  21292.0
# 15       2005  117566.0  190995.0  151381.0  21923.0
# 16       2006  121430.0  196323.0  156727.0  22216.0
# 17       2007  124058.0  193595.0  165660.0  23017.0
# 18       2008  122125.0  201813.0  175435.0  22601.0
# 19       2009  120944.0  207322.0  176626.0  22631.0
# 20       2010  121559.0  212735.0  187393.0  22752.0
# 21       2011  120044.0  213803.0  195006.0  22711.0
# 22       2012  120585.0  220506.0  200190.0  22825.0
# 23       2013  122724.0  225904.0  204474.0  23457.0
# 24       2014  121809.0  231298.0  208709.0  24075.0
# 25       2015  122418.0  232772.0  215781.0  24672.0
# 26       2016  124626.0  231306.0  222615.0  24927.0
# 27       2017  126266.0  232414.0  224835.0  25284.0
# 28       2018  128188.0  232923.0  228455.0  25552.0

# %%
fig = go.Figure()
# create a data trace for each type of meat and add them to figure one by one
fig.add_trace(go.Scatter(x=df_year_type_pivot.TIME, 
                         y=df_year_type_pivot.BEEF,
                         mode='lines+markers',
                         name='beef'))
fig.add_trace(go.Scatter(x=df_year_type_pivot.TIME, 
                         y=df_year_type_pivot.PIG,
                         mode='lines+markers',
                         name='pig'))
fig.add_trace(go.Scatter(x=df_year_type_pivot.TIME, 
                         y=df_year_type_pivot.POULTRY,
                         mode='lines+markers',
                         name='poultry'))
fig.add_trace(go.Scatter(x=df_year_type_pivot.TIME, 
                         y=df_year_type_pivot.SHEEP,
                         mode='lines+markers',
                         name='sheep'))
# edit the layout
fig.layout.update(title='Meat Consumption Evolution by Meat Type',
                   xaxis_title='Year',
                   yaxis_title='Meat consumption, thousand tonnes')
fig.show()
# Out:
# <div>
#
#
#             <div id="ce17da28-0f37-41e9-bda3-d170f2a694ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ce17da28-0f37-41e9-bda3-d170f2a694ac")) {
#                     Plotly.newPlot(
#                         'ce17da28-0f37-41e9-bda3-d170f2a694ac',
#                         [{"mode": "lines+markers", "name": "beef", "type": "scatter", "uid": "59a9bd1f-80aa-49b3-a46d-13f84e3712fc", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [71089.0, 74012.0, 82849.0, 83594.0, 86789.0, 88620.0, 89579.0, 91603.0, 91595.0, 93681.0, 108500.0, 108742.0, 112613.0, 114247.0, 115762.0, 117566.0, 121430.0, 124058.0, 122125.0, 120944.0, 121559.0, 120044.0, 120585.0, 122724.0, 121809.0, 122418.0, 124626.0, 126266.0, 128188.0]}, {"mode": "lines+markers", "name": "pig", "type": "scatter", "uid": "4310725d-de16-4898-85b4-84a2196ce6f8", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [84457.0, 89966.0, 95298.0, 105873.0, 111632.0, 113009.0, 112443.0, 120809.0, 128588.0, 129884.0, 173950.0, 177211.0, 181784.0, 184613.0, 186480.0, 190995.0, 196323.0, 193595.0, 201813.0, 207322.0, 212735.0, 213803.0, 220506.0, 225904.0, 231298.0, 232772.0, 231306.0, 232414.0, 232923.0]}, {"mode": "lines+markers", "name": "poultry", "type": "scatter", "uid": "9864a56e-b5c2-4e51-993a-3b5c9fecc596", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [50556.0, 61594.0, 68323.0, 73748.0, 78938.0, 85820.0, 87003.0, 92962.0, 96502.0, 101826.0, 127861.0, 132802.0, 139134.0, 142583.0, 146405.0, 151381.0, 156727.0, 165660.0, 175435.0, 176626.0, 187393.0, 195006.0, 200190.0, 204474.0, 208709.0, 215781.0, 222615.0, 224835.0, 228455.0]}, {"mode": "lines+markers", "name": "sheep", "type": "scatter", "uid": "cbcaa568-8c7b-4d96-bc24-b27de6568493", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [12101.0, 12845.0, 13728.0, 14234.0, 14700.0, 15144.0, 14421.0, 15241.0, 15777.0, 16019.0, 19851.0, 19728.0, 20016.0, 20529.0, 21292.0, 21923.0, 22216.0, 23017.0, 22601.0, 22631.0, 22752.0, 22711.0, 22825.0, 23457.0, 24075.0, 24672.0, 24927.0, 25284.0, 25552.0]}],
#                         {"title": {"text": "Meat Consumption Evolution by Meat Type"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Meat consumption, thousand tonnes"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ce17da28-0f37-41e9-bda3-d170f2a694ac');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Building Plotly graphs with Cufflinks
#
# The main advantage of using Cufflinks over native Plotly syntax is that it is much less verbose and can be used directly on pandas dataframe objects. You can find full Cufflinks documentation [here](https://plot.ly/ipython-notebooks/cufflinks/).
#
# Let's recreate the same line chart using cufflinks.

# %%
# Option 1: we can use iplot directly on the pandas series resulting from the groupby
df_total_clean.groupby('TIME').Value.sum().round(0).iplot(kind='line', 
                                                    title='Total Meat Consumption Evolution',
                                                    xTitle='Year',
                                                    yTitle='Meat consumption, thousand tonnes')
# Out:
# <div>
#
#
#             <div id="47510ac4-bdde-4d22-821a-fed52af7cbbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("47510ac4-bdde-4d22-821a-fed52af7cbbc")) {
#                     Plotly.newPlot(
#                         '47510ac4-bdde-4d22-821a-fed52af7cbbc',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Value", "text": "", "type": "scatter", "uid": "e15b075e-efe8-43ce-b9f2-065807c41295", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [218203.0, 238417.0, 260198.0, 277449.0, 292060.0, 302593.0, 303447.0, 320615.0, 332461.0, 341410.0, 430161.0, 438483.0, 453547.0, 461973.0, 469940.0, 481864.0, 496697.0, 506330.0, 521975.0, 527523.0, 544439.0, 551565.0, 564106.0, 576559.0, 585890.0, 595643.0, 603474.0, 608799.0, 615118.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Total Meat Consumption Evolution"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, thousand tonnes"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('47510ac4-bdde-4d22-821a-fed52af7cbbc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Option 2: we can use iplot on the df_total_year pandas Dataframe
# In this case we need to specify the x and y axis
df_total_year.iplot(kind='line', 
                    x='TIME',
                    y='Value',
                    title='Total Meat Consumption Evolution',
                    xTitle='Year',
                    yTitle='Meat consumption, thousand tonnes')
# Out:
# <div>
#
#
#             <div id="0489c30b-3146-45e3-8b91-957d4710a69d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0489c30b-3146-45e3-8b91-957d4710a69d")) {
#                     Plotly.newPlot(
#                         '0489c30b-3146-45e3-8b91-957d4710a69d',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Value", "text": "", "type": "scatter", "uid": "7af1c844-055d-451e-a459-6d566d0f4277", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [218203.0, 238417.0, 260198.0, 277449.0, 292060.0, 302593.0, 303447.0, 320615.0, 332461.0, 341410.0, 430161.0, 438483.0, 453547.0, 461973.0, 469940.0, 481864.0, 496697.0, 506330.0, 521975.0, 527523.0, 544439.0, 551565.0, 564106.0, 576559.0, 585890.0, 595643.0, 603474.0, 608799.0, 615118.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Total Meat Consumption Evolution"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, thousand tonnes"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0489c30b-3146-45e3-8b91-957d4710a69d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# In case of multiple lines graph, Cufflinks syntax will also be much less verbose than native Plotly syntax:

# %%
# Option 1: build a graph directly on the result of pivoting the dataframe

df_year_type.pivot_table(index='TIME', columns='SUBJECT', values='Value').\
iplot(kind='line', 
      mode='lines+markers',
      size=6,
      title='Meat Consumption Evolution by Meat Type',
      xTitle='Year',
      yTitle='Meat consumption, thousand tonnes')
# Out:
# <div>
#
#
#             <div id="32a1fc36-9b71-4be9-b1ae-ce7b3d910f88" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("32a1fc36-9b71-4be9-b1ae-ce7b3d910f88")) {
#                     Plotly.newPlot(
#                         '32a1fc36-9b71-4be9-b1ae-ce7b3d910f88',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "BEEF", "text": "", "type": "scatter", "uid": "889dda3e-0a60-480d-a8fc-4290607a500b", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [71089.0, 74012.0, 82849.0, 83594.0, 86789.0, 88620.0, 89579.0, 91603.0, 91595.0, 93681.0, 108500.0, 108742.0, 112613.0, 114247.0, 115762.0, 117566.0, 121430.0, 124058.0, 122125.0, 120944.0, 121559.0, 120044.0, 120585.0, 122724.0, 121809.0, 122418.0, 124626.0, 126266.0, 128188.0]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "PIG", "text": "", "type": "scatter", "uid": "f6744697-a0ad-4e54-ac33-ab25de2a2624", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [84457.0, 89966.0, 95298.0, 105873.0, 111632.0, 113009.0, 112443.0, 120809.0, 128588.0, 129884.0, 173950.0, 177211.0, 181784.0, 184613.0, 186480.0, 190995.0, 196323.0, 193595.0, 201813.0, 207322.0, 212735.0, 213803.0, 220506.0, 225904.0, 231298.0, 232772.0, 231306.0, 232414.0, 232923.0]}, {"line": {"color": "rgba(50, 171, 96, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "POULTRY", "text": "", "type": "scatter", "uid": "cdc91e41-e4f9-409a-8ba6-a7469cf42a58", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [50556.0, 61594.0, 68323.0, 73748.0, 78938.0, 85820.0, 87003.0, 92962.0, 96502.0, 101826.0, 127861.0, 132802.0, 139134.0, 142583.0, 146405.0, 151381.0, 156727.0, 165660.0, 175435.0, 176626.0, 187393.0, 195006.0, 200190.0, 204474.0, 208709.0, 215781.0, 222615.0, 224835.0, 228455.0]}, {"line": {"color": "rgba(128, 0, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "SHEEP", "text": "", "type": "scatter", "uid": "3997ab86-effe-417c-986b-2ef4b5e3c128", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [12101.0, 12845.0, 13728.0, 14234.0, 14700.0, 15144.0, 14421.0, 15241.0, 15777.0, 16019.0, 19851.0, 19728.0, 20016.0, 20529.0, 21292.0, 21923.0, 22216.0, 23017.0, 22601.0, 22631.0, 22752.0, 22711.0, 22825.0, 23457.0, 24075.0, 24672.0, 24927.0, 25284.0, 25552.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Meat Consumption Evolution by Meat Type"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, thousand tonnes"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('32a1fc36-9b71-4be9-b1ae-ce7b3d910f88');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Option 2: build a graph based on the df_year_type_pivot dataframe

df_year_type_pivot.iplot(kind='line',
                         mode='lines+markers',
                         size=6,
                         x='TIME',
                         title='Meat Consumption Evolution by Meat Type',
                         xTitle='Year',
                         yTitle='Meat consumption, thousand tonnes')
# Out:
# <div>
#
#
#             <div id="b3a85475-bec3-4f5f-b8c9-b3e66ee468d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b3a85475-bec3-4f5f-b8c9-b3e66ee468d8")) {
#                     Plotly.newPlot(
#                         'b3a85475-bec3-4f5f-b8c9-b3e66ee468d8',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "BEEF", "text": "", "type": "scatter", "uid": "f9d484b1-21a9-4dca-b211-bd2ff24a09d4", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [71089.0, 74012.0, 82849.0, 83594.0, 86789.0, 88620.0, 89579.0, 91603.0, 91595.0, 93681.0, 108500.0, 108742.0, 112613.0, 114247.0, 115762.0, 117566.0, 121430.0, 124058.0, 122125.0, 120944.0, 121559.0, 120044.0, 120585.0, 122724.0, 121809.0, 122418.0, 124626.0, 126266.0, 128188.0]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "PIG", "text": "", "type": "scatter", "uid": "73641e03-e8e5-4a9d-a1bd-376cf80cdf40", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [84457.0, 89966.0, 95298.0, 105873.0, 111632.0, 113009.0, 112443.0, 120809.0, 128588.0, 129884.0, 173950.0, 177211.0, 181784.0, 184613.0, 186480.0, 190995.0, 196323.0, 193595.0, 201813.0, 207322.0, 212735.0, 213803.0, 220506.0, 225904.0, 231298.0, 232772.0, 231306.0, 232414.0, 232923.0]}, {"line": {"color": "rgba(50, 171, 96, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "POULTRY", "text": "", "type": "scatter", "uid": "bfa92b9f-8f59-4a9f-ae49-d0b681d18f84", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [50556.0, 61594.0, 68323.0, 73748.0, 78938.0, 85820.0, 87003.0, 92962.0, 96502.0, 101826.0, 127861.0, 132802.0, 139134.0, 142583.0, 146405.0, 151381.0, 156727.0, 165660.0, 175435.0, 176626.0, 187393.0, 195006.0, 200190.0, 204474.0, 208709.0, 215781.0, 222615.0, 224835.0, 228455.0]}, {"line": {"color": "rgba(128, 0, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 6, "symbol": "circle"}, "mode": "lines+markers", "name": "SHEEP", "text": "", "type": "scatter", "uid": "f423f975-aadc-486f-9023-c9dfc862d663", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [12101.0, 12845.0, 13728.0, 14234.0, 14700.0, 15144.0, 14421.0, 15241.0, 15777.0, 16019.0, 19851.0, 19728.0, 20016.0, 20529.0, 21292.0, 21923.0, 22216.0, 23017.0, 22601.0, 22631.0, 22752.0, 22711.0, 22825.0, 23457.0, 24075.0, 24672.0, 24927.0, 25284.0, 25552.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Meat Consumption Evolution by Meat Type"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, thousand tonnes"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b3a85475-bec3-4f5f-b8c9-b3e66ee468d8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### PRACTICE TIME
#
# Create a bar chart showing total meat consumption in kg per capita per country (where each country is a bar) in year 2018 using either Plotly native syntax or Cufflinks.
#
# **BONUS POINTS!** Turn the bar chart into stacked bar chart by adding a split by type of meat.
#
# [Here](https://plot.ly/python/bar-charts/) is Plotly documentation for creating bar charts.
# [Here](https://plot.ly/ipython-notebooks/cufflinks/#bar-charts) is Cufflinks documentation for creating bar charts.
#
# Remember to filter the dataframe by year 2018 first and then summarize the meat consumption by country (hint: you can use pandas `groupby` funtion for that).

# %%
# start by filtering the df_per_cap dataset by year 2018
df_per_cap_2018 = df_per_cap.query('TIME == 2018')

# %%
# continue by summarizing meat consumption by country
series_country_2018 = df_per_cap_2018.groupby('LOCATION').Value.sum()

# %% [markdown]
# **Cufflinks option**

# %%
# create a bar chart
series_country_2018.iplot(kind='bar',
                          title='Meat Consumption by Country 2018',
                          xTitle='Country or Region',
                          yTitle='Meat consumption, kg per capita')
# Out:
# <div>
#
#
#             <div id="db64f985-1f69-47da-8dbd-1a20848bfb3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("db64f985-1f69-47da-8dbd-1a20848bfb3f")) {
#                     Plotly.newPlot(
#                         'db64f985-1f69-47da-8dbd-1a20848bfb3f',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Value", "orientation": "v", "text": "", "type": "bar", "uid": "9288d508-dd5c-46ef-8131-8db3698803c6", "x": ["ARG", "AUS", "BRA", "BRICS", "CAN", "CHE", "CHL", "CHN", "COL", "EGY", "ETH", "EU27", "GBR", "IDN", "IND", "IRN", "ISR", "JPN", "KAZ", "KOR", "MEX", "MYS", "NGA", "NOR", "NZL", "OECD", "PAK", "PER", "PHL", "PRY", "RUS", "SAU", "THA", "TUR", "UKR", "USA", "VNM", "WLD", "ZAF"], "y": [89.91005330543511, 92.22733540639831, 77.17698516558137, 32.18052195165564, 68.75004409585297, 51.241232185330695, 74.69657332727152, 48.9361149467184, 49.51526004058132, 20.221400145668014, 3.1745340289056414, 71.19762101397255, 60.921100116767136, 10.999146871287321, 3.558823142270648, 32.64804379458461, 88.29916136295492, 40.68809383753433, 47.33428079247822, 59.25720395690786, 51.5794510815214, 60.40619303520506, 5.133062647529938, 55.54324954293993, 74.88571428513362, 70.17744174173208, 14.380505411422018, 53.830155596615214, 31.5773958864056, 41.10640064900511, 62.8483680446371, 40.58240468412419, 19.228768797223847, 32.09723045320622, 38.841367978590654, 99.29194581368475, 52.49205715453023, 34.64012809012914, 52.07537070797505]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Meat Consumption by Country 2018"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country or Region"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, kg per capita"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('db64f985-1f69-47da-8dbd-1a20848bfb3f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# in order for bar chart to appear in descending order of meat consumption
# sort pandas series / dataframe by meat consumption 
# you can use sort_values method for that
series_country_2018.sort_values(ascending=False).iplot(kind='bar',
                                                       title='Meat Consumption by Country 2018',
                                                       xTitle='Country or Region',
                                                       yTitle='Meat consumption, kg per capita')
# Out:
# <div>
#
#
#             <div id="2823543f-12de-44a2-be68-5882a0b89137" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2823543f-12de-44a2-be68-5882a0b89137")) {
#                     Plotly.newPlot(
#                         '2823543f-12de-44a2-be68-5882a0b89137',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Value", "orientation": "v", "text": "", "type": "bar", "uid": "d19a6e82-a6ea-4c35-9682-94192a716366", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [99.29194581368475, 92.22733540639831, 89.91005330543511, 88.29916136295492, 77.17698516558137, 74.88571428513362, 74.69657332727152, 71.19762101397255, 70.17744174173208, 68.75004409585297, 62.8483680446371, 60.921100116767136, 60.40619303520506, 59.25720395690786, 55.54324954293993, 53.830155596615214, 52.49205715453023, 52.07537070797505, 51.5794510815214, 51.241232185330695, 49.51526004058132, 48.9361149467184, 47.33428079247822, 41.10640064900511, 40.68809383753433, 40.58240468412419, 38.841367978590654, 34.64012809012914, 32.64804379458461, 32.18052195165564, 32.09723045320622, 31.5773958864056, 20.221400145668014, 19.228768797223847, 14.380505411422018, 10.999146871287321, 5.133062647529938, 3.558823142270648, 3.1745340289056414]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Meat Consumption by Country 2018"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country or Region"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, kg per capita"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2823543f-12de-44a2-be68-5882a0b89137');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# create stacked bar chart

# start by pivoting the 2018 dataframe to have types of meat as columns and countries as rows
df_2018_pivot = df_per_cap_2018.pivot_table(index='LOCATION', columns='SUBJECT', values='Value')

# if you want the bars to appear ordered by total meat consumption, add total column and sort the dataframe by it
# you can use the .sum() method providing the necessary axis as an argument
df_2018_pivot['total'] = df_2018_pivot.sum(axis=1)
df_2018_pivot = df_2018_pivot.sort_values(by='total', ascending=False)

# drop the total column after the sorting so that it doesn't appear on the graph
df_2018_pivot = df_2018_pivot.drop(columns='total')

# create a stacked bar chart (use barmode='stack')
df_2018_pivot.iplot(kind='bar', 
                    barmode='stack',
                    title='Meat Consumption by Country and Meat Type 2018',
                    xTitle='Country or Region',
                    yTitle='Meat consumption, kg per capita')
# Out:
# <div>
#
#
#             <div id="42e4f7b6-063d-4dc6-a635-0b1cf3dad93e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("42e4f7b6-063d-4dc6-a635-0b1cf3dad93e")) {
#                     Plotly.newPlot(
#                         '42e4f7b6-063d-4dc6-a635-0b1cf3dad93e',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "BEEF", "orientation": "v", "text": "", "type": "bar", "uid": "9a5640a3-f645-4012-83f3-1c06b6127e6f", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [26.0908679404035, 18.9106714885412, 39.9271744746074, 20.4622062652522, 24.4725008239042, 11.8545279101498, 18.742340076512, 10.782510632553999, 14.4841483898346, 17.966153705183498, 10.4101573318821, 11.673392876241, 5.22119979241409, 10.9040600174711, 13.6551678322076, 4.163597932343911, 9.269576446333721, 12.2466430622413, 8.851118921512981, 13.272419913123, 10.7543428273755, 3.80350349023303, 19.2649847391045, 13.6853579523716, 7.4361151174256515, 3.98458306906986, 5.00236304559441, 6.40849523540783, 5.404806474197391, 4.226012712977069, 8.524432993662879, 3.12828460682823, 7.85543854703919, 1.30351150657742, 6.40013638391254, 1.98249635436634, 1.3464610753746298, 0.5170444776092771, 2.56862297730969]}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "PIG", "orientation": "v", "text": "", "type": "bar", "uid": "b8275f91-4fad-4b0f-9759-1478eadfebb9", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [23.049306858271297, 21.9064436513338, 10.838643001531699, 1.3839747324894198, 12.334839681614199, 18.908015864476198, 18.998276431363802, 35.459971798399295, 23.7074987396175, 16.0446999235398, 19.641641768036198, 17.363121953743, 5.3579287281072006, 30.0615457546156, 20.2213020682451, 4.14529727694052, 29.694535258860803, 3.45010157332287, 13.451457127939, 22.549076700771604, 7.9654666885520315, 30.437704229342494, 4.85702889749528, 21.638994236547894, 16.168831047278303, 0.506762373877128, 12.5002516589876, 12.3162558870509, 0.017120452012227, 15.381057741291801, 1.8091512304176003e-06, 14.9251652575687, 0.00728465528637263, 9.955820087604849, 7.3799704920309e-07, 1.02044545628306, 1.1221637742187198, 0.17333026434505305, 0.0148558126822883]}, {"marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "name": "POULTRY", "orientation": "v", "text": "", "type": "bar", "uid": "d048c7e7-a61c-4328-b13e-eee190e8f2fa", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [49.682861865303295, 44.1278736953786, 38.1822211457423, 64.8666914647893, 39.8116836772647, 39.4109364656461, 36.5379845612914, 23.5545635499994, 30.6400183241462, 33.788648531206, 31.42069890725, 27.7926608964431, 48.7010008361708, 17.9906233290605, 17.186386965338098, 44.4668304993799, 13.363784401856199, 33.7474290538803, 28.7570106836333, 14.266181079494698, 30.652982650263706, 11.5549102257081, 14.9946902649495, 5.28059361149429, 16.9205122490068, 32.2352534028287, 21.0627490680885, 14.165341198736801, 23.008546582224998, 10.832777236267901, 19.2651739453079, 13.013685638181501, 11.2604619905748, 7.9263792178282095, 5.93564791764511, 7.56510548022657, 0.889586735756938, 2.40490758099648, 0.114772875010489]}, {"marker": {"color": "rgba(128, 0, 128, 0.6)", "line": {"color": "rgba(128, 0, 128, 1.0)", "width": 1}}, "name": "SHEEP", "orientation": "v", "text": "", "type": "bar", "uid": "b0ae0c5d-9fe4-4dc6-beaf-a09fda179bfe", "x": ["USA", "AUS", "ARG", "ISR", "BRA", " ...
#                         {"barmode": "stack", "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}, "traceorder": "normal"}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Meat Consumption by Country and Meat Type 2018"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country or Region"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Meat consumption, kg per capita"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('42e4f7b6-063d-4dc6-a635-0b1cf3dad93e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# **Plotly Option**

# %%
# create a bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=series_country_2018.index,
                     y=series_country_2018))
fig.layout.update(title='Meat Consumption by Country 2018',
                   xaxis_title='Country or Region',
                   yaxis_title='Meat consumption, kg per capita')
fig.show()
# Out:
# <div>
#
#
#             <div id="de8ad412-ea78-4f6f-96d9-2c35a55ce2b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("de8ad412-ea78-4f6f-96d9-2c35a55ce2b2")) {
#                     Plotly.newPlot(
#                         'de8ad412-ea78-4f6f-96d9-2c35a55ce2b2',
#                         [{"type": "bar", "uid": "4c2c7fa2-fa9a-43ce-bee6-6bd533c14898", "x": ["ARG", "AUS", "BRA", "BRICS", "CAN", "CHE", "CHL", "CHN", "COL", "EGY", "ETH", "EU27", "GBR", "IDN", "IND", "IRN", "ISR", "JPN", "KAZ", "KOR", "MEX", "MYS", "NGA", "NOR", "NZL", "OECD", "PAK", "PER", "PHL", "PRY", "RUS", "SAU", "THA", "TUR", "UKR", "USA", "VNM", "WLD", "ZAF"], "y": [89.91005330543511, 92.22733540639831, 77.17698516558137, 32.18052195165564, 68.75004409585297, 51.241232185330695, 74.69657332727152, 48.9361149467184, 49.51526004058132, 20.221400145668014, 3.1745340289056414, 71.19762101397255, 60.921100116767136, 10.999146871287321, 3.558823142270648, 32.64804379458461, 88.29916136295492, 40.68809383753433, 47.33428079247822, 59.25720395690786, 51.5794510815214, 60.40619303520506, 5.133062647529938, 55.54324954293993, 74.88571428513362, 70.17744174173208, 14.380505411422018, 53.830155596615214, 31.5773958864056, 41.10640064900511, 62.8483680446371, 40.58240468412419, 19.228768797223847, 32.09723045320622, 38.841367978590654, 99.29194581368475, 52.49205715453023, 34.64012809012914, 52.07537070797505]}],
#                         {"title": {"text": "Meat Consumption by Country 2018"}, "xaxis": {"title": {"text": "Country or Region"}}, "yaxis": {"title": {"text": "Meat consumption, kg per capita"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('de8ad412-ea78-4f6f-96d9-2c35a55ce2b2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# create a sorted bar chart
series_country_2018_sorted = series_country_2018.sort_values(ascending=False)

fig = go.Figure()
fig.add_trace(go.Bar(x=series_country_2018_sorted.index,
                     y=series_country_2018_sorted))
fig.layout.update(title='Meat Consumption by Country 2018',
                   xaxis_title='Country or Region',
                   yaxis_title='Meat consumption, kg per capita')
fig.show()
# Out:
# <div>
#
#
#             <div id="0923aae3-6db5-4074-96e8-957c7af8e0a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0923aae3-6db5-4074-96e8-957c7af8e0a5")) {
#                     Plotly.newPlot(
#                         '0923aae3-6db5-4074-96e8-957c7af8e0a5',
#                         [{"type": "bar", "uid": "11544c75-59db-4b61-85a6-7cc307e8d2b7", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [99.29194581368475, 92.22733540639831, 89.91005330543511, 88.29916136295492, 77.17698516558137, 74.88571428513362, 74.69657332727152, 71.19762101397255, 70.17744174173208, 68.75004409585297, 62.8483680446371, 60.921100116767136, 60.40619303520506, 59.25720395690786, 55.54324954293993, 53.830155596615214, 52.49205715453023, 52.07537070797505, 51.5794510815214, 51.241232185330695, 49.51526004058132, 48.9361149467184, 47.33428079247822, 41.10640064900511, 40.68809383753433, 40.58240468412419, 38.841367978590654, 34.64012809012914, 32.64804379458461, 32.18052195165564, 32.09723045320622, 31.5773958864056, 20.221400145668014, 19.228768797223847, 14.380505411422018, 10.999146871287321, 5.133062647529938, 3.558823142270648, 3.1745340289056414]}],
#                         {"title": {"text": "Meat Consumption by Country 2018"}, "xaxis": {"title": {"text": "Country or Region"}}, "yaxis": {"title": {"text": "Meat consumption, kg per capita"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0923aae3-6db5-4074-96e8-957c7af8e0a5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# create stacked bar chart

# start by pivoting the 2018 dataframe to have types of meat as columns and countries as rows
df_2018_pivot = df_per_cap_2018.pivot_table(index='LOCATION', columns='SUBJECT', values='Value')

# if you want the bars to appear ordered by total meat consumption, add total column and sort the dataframe by it
# you can use the .sum() method providing the necessary axis as an argument
df_2018_pivot['total'] = df_2018_pivot.sum(axis=1)
df_2018_pivot = df_2018_pivot.sort_values(by='total', ascending=False)

# drop the total column after the sorting so that it doesn't appear on the graph
df_2018_pivot = df_2018_pivot.drop(columns='total')

# create a stacked bar chart (use barmode='stack')
fig = go.Figure()
fig.add_trace(go.Bar(x=df_2018_pivot.index,
                     y=df_2018_pivot.BEEF,
                     name='beef',
                     marker_color='darkred'))
fig.add_trace(go.Bar(x=df_2018_pivot.index,
                     y=df_2018_pivot.PIG,
                     name='pig',
                     marker_color='indianred'))
fig.add_trace(go.Bar(x=df_2018_pivot.index,
                     y=df_2018_pivot.POULTRY,
                     name='poultry',
                     marker_color='lightsalmon'))
fig.add_trace(go.Bar(x=df_2018_pivot.index,
                     y=df_2018_pivot.SHEEP,
                     name='sheep',
                     marker_color='peachpuff'))
fig.layout.update(barmode='stack',
                  title='Meat Consumption by Country and Meat Type 2018',
                  xaxis_title='Country or Region',
                  yaxis_title='Meat consumption, kg per capita')

# Change the bar mode
fig.show()
# Out:
# <div>
#
#
#             <div id="c3b8bdf3-b510-430d-9bdf-9bbed7aba808" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c3b8bdf3-b510-430d-9bdf-9bbed7aba808")) {
#                     Plotly.newPlot(
#                         'c3b8bdf3-b510-430d-9bdf-9bbed7aba808',
#                         [{"marker": {"color": "darkred"}, "name": "beef", "type": "bar", "uid": "ddea4129-0809-488e-89f5-728165151088", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [26.0908679404035, 18.9106714885412, 39.9271744746074, 20.4622062652522, 24.4725008239042, 11.8545279101498, 18.742340076512, 10.782510632553999, 14.4841483898346, 17.966153705183498, 10.4101573318821, 11.673392876241, 5.22119979241409, 10.9040600174711, 13.6551678322076, 4.163597932343911, 9.269576446333721, 12.2466430622413, 8.851118921512981, 13.272419913123, 10.7543428273755, 3.80350349023303, 19.2649847391045, 13.6853579523716, 7.4361151174256515, 3.98458306906986, 5.00236304559441, 6.40849523540783, 5.404806474197391, 4.226012712977069, 8.524432993662879, 3.12828460682823, 7.85543854703919, 1.30351150657742, 6.40013638391254, 1.98249635436634, 1.3464610753746298, 0.5170444776092771, 2.56862297730969]}, {"marker": {"color": "indianred"}, "name": "pig", "type": "bar", "uid": "27226d7f-3752-48b6-b777-6a5961915fd2", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [23.049306858271297, 21.9064436513338, 10.838643001531699, 1.3839747324894198, 12.334839681614199, 18.908015864476198, 18.998276431363802, 35.459971798399295, 23.7074987396175, 16.0446999235398, 19.641641768036198, 17.363121953743, 5.3579287281072006, 30.0615457546156, 20.2213020682451, 4.14529727694052, 29.694535258860803, 3.45010157332287, 13.451457127939, 22.549076700771604, 7.9654666885520315, 30.437704229342494, 4.85702889749528, 21.638994236547894, 16.168831047278303, 0.506762373877128, 12.5002516589876, 12.3162558870509, 0.017120452012227, 15.381057741291801, 1.8091512304176003e-06, 14.9251652575687, 0.00728465528637263, 9.955820087604849, 7.3799704920309e-07, 1.02044545628306, 1.1221637742187198, 0.17333026434505305, 0.0148558126822883]}, {"marker": {"color": "lightsalmon"}, "name": "poultry", "type": "bar", "uid": "4bcb3d07-d8ba-4e5f-8dd6-d2ef91923fc3", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [49.682861865303295, 44.1278736953786, 38.1822211457423, 64.8666914647893, 39.8116836772647, 39.4109364656461, 36.5379845612914, 23.5545635499994, 30.6400183241462, 33.788648531206, 31.42069890725, 27.7926608964431, 48.7010008361708, 17.9906233290605, 17.186386965338098, 44.4668304993799, 13.363784401856199, 33.7474290538803, 28.7570106836333, 14.266181079494698, 30.652982650263706, 11.5549102257081, 14.9946902649495, 5.28059361149429, 16.9205122490068, 32.2352534028287, 21.0627490680885, 14.165341198736801, 23.008546582224998, 10.832777236267901, 19.2651739453079, 13.013685638181501, 11.2604619905748, 7.9263792178282095, 5.93564791764511, 7.56510548022657, 0.889586735756938, 2.40490758099648, 0.114772875010489]}, {"marker": {"color": "peachpuff"}, "name": "sheep", "type": "bar", "uid": "850d3459-cc2a-4e23-b8d6-68cd1fada679", "x": ["USA", "AUS", "ARG", "ISR", "BRA", "NZL", "CHL", "EU27", "OECD", "CAN", "RUS", "GBR", "MYS", "KOR", "NOR", "PER", "VNM", "ZAF", "MEX", "CHE", "COL", "CHN", "KAZ", "PRY", "JPN", "SAU", "UKR", "WLD", "IRN", "BRICS", "TUR", "PHL", "EGY", "THA", "PAK", "IDN", "NGA", "IND", "ETH"], "y": [0.468909149706659, 7.28234657114472, 0.962014683553722, 1.58628890042399, 0.557960982798268, 4.7122340448615185, 0.417972258104324, 1.40057503301985, 1.345776288133 ...
#                         {"barmode": "stack", "title": {"text": "Meat Consumption by Country and Meat Type 2018"}, "xaxis": {"title": {"text": "Country or Region"}}, "yaxis": {"title": {"text": "Meat consumption, kg per capita"}}},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c3b8bdf3-b510-430d-9bdf-9bbed7aba808');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
